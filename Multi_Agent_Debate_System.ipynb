# %% [markdown]
# <a href="https://colab.research.google.com/github/Swastikraj599/Multi-Agent-Debate-System/blob/main/Multi_Agent_Debate_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries
# !pip install -q transformers accelerate bitsandbytes gradio huggingface_hub
print("✅ Installation complete!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 14.4 MB/s eta 0:00:00
# ✅ Installation complete!

# %%
import gradio as gr
import time
import random
from transformers import pipeline

print("✅ All libraries imported!")
# Out:
# ✅ All libraries imported!

# %%
from transformers import pipeline
import random

# Use a local model that works without API
generator = pipeline('text-generation', model='gpt2', device=-1)

class DebateAgent:
    def __init__(self, name, role, expertise, stance):
        self.name = name
        self.role = role
        self.expertise = expertise
        self.stance = stance

    def generate_argument(self, topic, conversation_history="", opponent_argument=""):
        """Generate an argument based on the agent's perspective"""

        prompt = f"{self.name} argues: {self.stance} regarding {topic}. "

        try:
            # Generate response
            response = generator(
                prompt,
                max_length=100,
                num_return_sequences=1,
                temperature=0.8,
                do_sample=True,
                pad_token_id=50256
            )[0]['generated_text']

            # Extract only the new generated part
            argument = response[len(prompt):].strip()

            # Clean up the argument
            sentences = argument.split('.')
            argument = '. '.join(sentences[:3]) + '.'

            return argument if argument else f"I believe {self.stance.lower()} This perspective considers {self.expertise}."

        except Exception as e:
            # Fallback responses based on agent stance
            fallback_args = {
                "Cautious": f"Regarding {topic}, we must proceed carefully. The risks of moving too quickly without proper safeguards could have serious consequences. My expertise in {self.expertise} shows that a measured approach is essential.",
                "Optimistic": f"I believe {topic} presents tremendous opportunities. Innovation thrives when we embrace change and allow progress to move forward. Based on my experience in {self.expertise}, rapid advancement benefits everyone.",
                "Balanced": f"Considering {topic}, we need to weigh both benefits and risks carefully. My work in {self.expertise} has shown that the best solutions come from thoughtful analysis of multiple perspectives."
            }

            for key in fallback_args:
                if key.lower() in self.stance.lower():
                    return fallback_args[key]

            return f"From my perspective as a {self.role}, {topic} requires careful consideration of multiple factors including {self.expertise}."

# Create three debate agents with different perspectives
def create_agents(topic=""):
    agent1 = DebateAgent(
        name="Dr. Sarah Chen",
        role="AI Ethics Researcher",
        expertise="artificial intelligence safety and ethics",
        stance="Cautious - believes we need strong safeguards and careful consideration"
    )

    agent2 = DebateAgent(
        name="Marcus Rivera",
        role="Tech Entrepreneur",
        expertise="innovation and business growth",
        stance="Optimistic - believes in rapid innovation and market-driven solutions"
    )

    agent3 = DebateAgent(
        name="Prof. Anika Sharma",
        role="Policy Expert",
        expertise="balancing innovation with public interest",
        stance="Balanced - seeks evidence-based middle ground approaches"
    )

    return [agent1, agent2, agent3]

print("✅ Agent system created successfully!")
print("✅ Using local model - no API needed!")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ...

# %%
def run_debate(topic, num_rounds=3):
    """
    Run a multi-agent debate on the given topic
    """
    agents = create_agents()

    debate_output = f"🎭 **MULTI-AGENT DEBATE SYSTEM**\n\n"
    debate_output += f"📋 **Topic:** {topic}\n"
    debate_output += f"👥 **Participants:** {agents[0].name}, {agents[1].name}, {agents[2].name}\n"
    debate_output += f"{'='*80}\n\n"

    conversation_history = ""

    for round_num in range(1, num_rounds + 1):
        debate_output += f"### 🔄 Round {round_num}\n\n"

        # Each agent speaks in turn
        for i, agent in enumerate(agents):
            # Get previous agent's argument if available
            previous_arg = ""
            if i > 0:
                previous_arg = agents[i-1].name + "'s argument"

            debate_output += f"**{agent.name}** ({agent.role}):\n"

            # Generate argument
            argument = agent.generate_argument(
                topic=topic,
                conversation_history=conversation_history[:500],  # Keep context manageable
                opponent_argument=previous_arg
            )

            debate_output += f"{argument}\n\n"

            # Update conversation history
            conversation_history += f"{agent.name}: {argument}\n"

            # Small delay to avoid rate limits
            time.sleep(1)

        debate_output += f"{'-'*80}\n\n"

    # Generate conclusion
    debate_output += "### 🎯 Debate Summary\n\n"
    debate_output += "The debate explored multiple perspectives:\n"
    debate_output += f"- **{agents[0].name}** emphasized cautious, safety-focused approach\n"
    debate_output += f"- **{agents[1].name}** advocated for innovation and rapid progress\n"
    debate_output += f"- **{agents[2].name}** sought balanced middle ground\n\n"
    debate_output += "All perspectives offer valuable insights for informed decision-making."

    return debate_output

print("✅ Debate orchestrator ready!")
# Out:
# ✅ Debate orchestrator ready!

# %%
def run_debate_enhanced(topic, num_rounds=3):
    """
    Enhanced debate with scoring and analysis
    """
    agents = create_agents()

    debate_output = f"""
# 🎭 MULTI-AGENT DEBATE SYSTEM

## 📋 Topic: {topic}

### 👥 Debate Participants:
- **{agents[0].name}** - {agents[0].role} | Stance: {agents[0].stance}
- **{agents[1].name}** - {agents[1].role} | Stance: {agents[1].stance}
- **{agents[2].name}** - {agents[2].role} | Stance: {agents[2].stance}

---

"""

    conversation_history = ""
    agent_scores = {agent.name: 0 for agent in agents}

    for round_num in range(1, num_rounds + 1):
        debate_output += f"\n## 🔄 Round {round_num}\n\n"

        round_arguments = []

        # Each agent speaks in turn
        for i, agent in enumerate(agents):
            previous_arg = round_arguments[-1] if round_arguments else ""

            debate_output += f"### 💬 {agent.name}\n"
            debate_output += f"*{agent.role}*\n\n"

            # Generate argument
            argument = agent.generate_argument(
                topic=topic,
                conversation_history=conversation_history[:300],
                opponent_argument=previous_arg
            )

            debate_output += f"{argument}\n\n"

            # Simple scoring based on argument length and keywords
            score = len(argument.split())
            quality_keywords = ['evidence', 'research', 'data', 'study', 'however', 'therefore', 'because', 'consider']
            score += sum(2 for word in quality_keywords if word in argument.lower())
            agent_scores[agent.name] += score

            round_arguments.append(argument)
            conversation_history += f"{agent.name}: {argument}\n"

        debate_output += f"\n---\n"

    # Final Analysis
    debate_output += f"\n## 🎯 Debate Analysis\n\n"

    # Sort agents by score
    ranked_agents = sorted(agent_scores.items(), key=lambda x: x[1], reverse=True)

    debate_output += "### 📊 Argument Strength Scores:\n\n"
    medals = ["🥇", "🥈", "🥉"]
    for idx, (agent_name, score) in enumerate(ranked_agents):
        medal = medals[idx] if idx < 3 else "🏅"
        debate_output += f"{medal} **{agent_name}**: {score} points\n"

    debate_output += f"\n### 💡 Key Takeaways:\n\n"
    debate_output += f"- **Cautious Perspective**: Emphasized safety and careful consideration\n"
    debate_output += f"- **Optimistic Perspective**: Highlighted innovation and opportunities\n"
    debate_output += f"- **Balanced Perspective**: Sought middle ground with evidence-based approach\n\n"

    debate_output += f"### ✅ Conclusion:\n\n"
    debate_output += f"This multi-agent debate demonstrated diverse viewpoints on **{topic}**. "
    debate_output += f"Each agent contributed unique insights based on their expertise, "
    debate_output += f"showcasing how AI systems can simulate expert panel discussions for complex decision-making.\n"

    return debate_output

print("✅ Enhanced debate system ready!")
# Out:
# ✅ Enhanced debate system ready!

# %%
# Create a beautiful Gradio interface
def debate_interface(topic, rounds):
    """Gradio interface function"""
    if not topic.strip():
        return "⚠️ Please enter a debate topic!"

    #output = run_debate(topic, int(rounds))
    output = run_debate_enhanced(topic, int(rounds))
    return output

# Build the interface
with gr.Blocks(theme=gr.themes.Soft()) as demo:
    gr.Markdown("""
    # 🤖 Multi-Agent AI Debate System
    ### Watch AI agents debate complex topics from different perspectives

    This system simulates expert panel discussions where multiple AI agents
    with different expertise and viewpoints engage in structured debates.
    """)

    with gr.Row():
        with gr.Column():
            topic_input = gr.Textbox(
                label="Debate Topic",
                placeholder="e.g., Should AI development be regulated?",
                lines=2
            )
            rounds_input = gr.Slider(
                minimum=1,
                maximum=5,
                value=3,
                step=1,
                label="Number of Rounds"
            )
            debate_btn = gr.Button("🎬 Start Debate", variant="primary", size="lg")

    output_box = gr.Markdown(label="Debate Output")

    # Examples
    gr.Examples(
        examples=[
            ["Should AI development be regulated by governments?", 3],
            ["Is remote work better than office work for productivity?", 3],
            ["Should social media companies be responsible for content moderation?", 2],
        ],
        inputs=[topic_input, rounds_input]
    )

    debate_btn.click(
        fn=debate_interface,
        inputs=[topic_input, rounds_input],
        outputs=output_box
    )

# Add ability to save debates
def save_debate(debate_text, topic):
    """Save debate to a text file"""
    filename = f"debate_{topic[:30].replace(' ', '_')}.txt"
    with open(filename, 'w', encoding='utf-8') as f:
        f.write(debate_text)
    return f"✅ Debate saved as {filename}"

print("✅ Export feature added!")
print("✅ Interface created!")
print("🚀 Launching demo...")

# Launch the interface
demo.launch(share=True, debug=True)
# Out:
# /tmp/ipython-input-246/1890147794.py:12: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=gr.themes.Soft()) as demo:
# ✅ Export feature added!
# ✅ Interface created!
# 🚀 Launching demo...
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://a9049431eba31bb37c.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://a9049431eba31bb37c.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ...

# %%
# Install all required libraries
# !pip install -q transformers accelerate bitsandbytes gradio huggingface_hub reportlab
print("✅ All libraries installed!")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 18.2 MB/s eta 0:00:00
# ✅ All libraries installed!

# %%
import gradio as gr
import time
import random
import json
import os
from datetime import datetime
from transformers import pipeline
from reportlab.lib.pagesizes import letter
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.units import inch
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.enums import TA_CENTER, TA_LEFT
from reportlab.lib.colors import HexColor

# Initialize the text generation model
print("Loading model...")
generator = pipeline('text-generation', model='gpt2', device=-1)
print("✅ Model loaded successfully!")

# File to store debate history
HISTORY_FILE = "debate_history.json"
# Out:
# Loading model...
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ Model loaded successfully!

# %%
class DebateAgent:
    def __init__(self, name, role, expertise, stance):
        self.name = name
        self.role = role
        self.expertise = expertise
        self.stance = stance

    def generate_argument(self, topic, conversation_history="", opponent_argument=""):
        """Generate an argument based on the agent's perspective"""

        prompt = f"{self.name} argues: {self.stance} regarding {topic}. "

        try:
            response = generator(
                prompt,
                max_length=100,
                num_return_sequences=1,
                temperature=0.8,
                do_sample=True,
                pad_token_id=50256
            )[0]['generated_text']

            argument = response[len(prompt):].strip()
            sentences = argument.split('.')
            argument = '. '.join(sentences[:3]) + '.'

            return argument if argument else f"I believe {self.stance.lower()} This perspective considers {self.expertise}."

        except Exception as e:
            fallback_args = {
                "Cautious": f"Regarding {topic}, we must proceed carefully. The risks of moving too quickly without proper safeguards could have serious consequences. My expertise in {self.expertise} shows that a measured approach is essential.",
                "Optimistic": f"I believe {topic} presents tremendous opportunities. Innovation thrives when we embrace change and allow progress to move forward. Based on my experience in {self.expertise}, rapid advancement benefits everyone.",
                "Balanced": f"Considering {topic}, we need to weigh both benefits and risks carefully. My work in {self.expertise} has shown that the best solutions come from thoughtful analysis of multiple perspectives."
            }

            for key in fallback_args:
                if key.lower() in self.stance.lower():
                    return fallback_args[key]

            return f"From my perspective as a {self.role}, {topic} requires careful consideration of multiple factors including {self.expertise}."

def create_custom_agents(agent1_name, agent1_role, agent1_stance,
                        agent2_name, agent2_role, agent2_stance,
                        agent3_name, agent3_role, agent3_stance):
    """Create custom agents based on user input"""

    agent1 = DebateAgent(
        name=agent1_name if agent1_name.strip() else "Agent 1",
        role=agent1_role if agent1_role.strip() else "Debater",
        expertise=agent1_role if agent1_role.strip() else "general topics",
        stance=agent1_stance if agent1_stance.strip() else "Cautious approach"
    )

    agent2 = DebateAgent(
        name=agent2_name if agent2_name.strip() else "Agent 2",
        role=agent2_role if agent2_role.strip() else "Debater",
        expertise=agent2_role if agent2_role.strip() else "general topics",
        stance=agent2_stance if agent2_stance.strip() else "Optimistic approach"
    )

    agent3 = DebateAgent(
        name=agent3_name if agent3_name.strip() else "Agent 3",
        role=agent3_role if agent3_role.strip() else "Debater",
        expertise=agent3_role if agent3_role.strip() else "general topics",
        stance=agent3_stance if agent3_stance.strip() else "Balanced approach"
    )

    return [agent1, agent2, agent3]

def create_default_agents():
    """Create default debate agents"""
    agent1 = DebateAgent(
        name="Dr. Sarah Chen",
        role="AI Ethics Researcher",
        expertise="artificial intelligence safety and ethics",
        stance="Cautious - believes we need strong safeguards and careful consideration"
    )

    agent2 = DebateAgent(
        name="Marcus Rivera",
        role="Tech Entrepreneur",
        expertise="innovation and business growth",
        stance="Optimistic - believes in rapid innovation and market-driven solutions"
    )

    agent3 = DebateAgent(
        name="Prof. Anika Sharma",
        role="Policy Expert",
        expertise="balancing innovation with public interest",
        stance="Balanced - seeks evidence-based middle ground approaches"
    )

    return [agent1, agent2, agent3]

print("✅ Agent system created!")
# Out:
# ✅ Agent system created!

# %%
def save_debate_to_history(debate_data):
    """Save debate to history file"""
    try:
        if os.path.exists(HISTORY_FILE):
            with open(HISTORY_FILE, 'r') as f:
                history = json.load(f)
        else:
            history = []

        history.append(debate_data)

        # Keep only last 50 debates
        if len(history) > 50:
            history = history[-50:]

        with open(HISTORY_FILE, 'w') as f:
            json.dump(history, f, indent=2)
    except Exception as e:
        print(f"Error saving history: {e}")

def load_debate_history():
    """Load debate history"""
    try:
        if os.path.exists(HISTORY_FILE):
            with open(HISTORY_FILE, 'r') as f:
                return json.load(f)
        return []
    except Exception as e:
        print(f"Error loading history: {e}")
        return []

def format_history_for_display():
    """Format debate history for display"""
    history = load_debate_history()

    if not history:
        return "📝 No debate history yet. Start your first debate!"

    output = "# 📚 Debate History\n\n"
    output += f"**Total Debates:** {len(history)}\n\n---\n\n"

    for idx, debate in enumerate(reversed(history[-10:])):  # Show last 10
        output += f"## Debate #{len(history) - idx}\n\n"
        output += f"**Topic:** {debate['topic']}\n\n"
        output += f"**Date:** {debate['date']}\n\n"
        output += f"**Participants:** {', '.join([a['name'] for a in debate['agents']])}\n\n"
        output += f"**Winner:** {list(debate['scores'].keys())[0]} ({debate['scores'][list(debate['scores'].keys())[0]]} points)\n\n"
        output += "---\n\n"

    return output

def load_specific_debate(debate_number):
    """Load a specific debate from history"""
    history = load_debate_history()

    if not history or debate_number < 1 or debate_number > len(history):
        return "❌ Debate not found!"

    debate = history[debate_number - 1]

    output = f"# 🎭 Debate #{debate_number}\n\n"
    output += f"## 📋 Topic: {debate['topic']}\n\n"
    output += f"**Date:** {debate['date']}\n\n"

    output += "### 👥 Participants:\n"
    for agent in debate['agents']:
        output += f"- **{agent['name']}** - {agent['role']}\n"

    output += "\n---\n\n"

    for round_data in debate['rounds']:
        output += f"## Round {round_data['round_number']}\n\n"
        for arg_data in round_data['arguments']:
            output += f"**{arg_data['agent']}:**\n{arg_data['argument']}\n\n"
        output += "---\n\n"

    output += "## 📊 Final Scores:\n\n"
    medals = ["🥇", "🥈", "🥉"]
    for idx, (agent, score) in enumerate(debate['scores'].items()):
        medal = medals[idx] if idx < 3 else "🏅"
        output += f"{medal} **{agent}**: {score} points\n"

    return output

print("✅ History functions ready!")
# Out:
# ✅ History functions ready!

# %%
def export_debate_to_pdf(debate_data, filename="debate_output.pdf"):
    """Export debate to PDF"""
    try:
        doc = SimpleDocTemplate(filename, pagesize=letter)
        styles = getSampleStyleSheet()
        story = []

        # Custom styles
        title_style = ParagraphStyle(
            'CustomTitle',
            parent=styles['Heading1'],
            fontSize=24,
            textColor=HexColor('#2563eb'),
            spaceAfter=30,
            alignment=TA_CENTER
        )

        heading_style = ParagraphStyle(
            'CustomHeading',
            parent=styles['Heading2'],
            fontSize=14,
            textColor=HexColor('#1e40af'),
            spaceAfter=12,
            spaceBefore=12
        )

        # Title
        story.append(Paragraph("🎭 Multi-Agent AI Debate System", title_style))
        story.append(Spacer(1, 0.2*inch))

        # Topic
        story.append(Paragraph(f"<b>Topic:</b> {debate_data['topic']}", styles['Normal']))
        story.append(Paragraph(f"<b>Date:</b> {debate_data['date']}", styles['Normal']))
        story.append(Spacer(1, 0.3*inch))

        # Participants
        story.append(Paragraph("Debate Participants", heading_style))
        for agent in debate_data['agents']:
            story.append(Paragraph(f"• <b>{agent['name']}</b> - {agent['role']}", styles['Normal']))
            story.append(Paragraph(f"  Stance: {agent['stance']}", styles['Normal']))
            story.append(Spacer(1, 0.1*inch))

        story.append(Spacer(1, 0.3*inch))

        # Rounds
        for round_data in debate_data['rounds']:
            story.append(Paragraph(f"Round {round_data['round_number']}", heading_style))

            for arg_data in round_data['arguments']:
                story.append(Paragraph(f"<b>{arg_data['agent']}</b>", styles['Normal']))
                story.append(Paragraph(arg_data['argument'], styles['Normal']))
                story.append(Spacer(1, 0.15*inch))

            story.append(Spacer(1, 0.2*inch))

        # Scores
        story.append(Paragraph("Final Scores", heading_style))
        medals = ["🥇 ", "🥈 ", "🥉 "]
        for idx, (agent, score) in enumerate(debate_data['scores'].items()):
            medal = medals[idx] if idx < 3 else "🏅 "
            story.append(Paragraph(f"{medal}<b>{agent}</b>: {score} points", styles['Normal']))

        # Build PDF
        doc.build(story)

        return filename
    except Exception as e:
        print(f"Error creating PDF: {e}")
        return None

print("✅ PDF export function ready!")
# Out:
# ✅ PDF export function ready!

# %%
def run_debate_enhanced(topic, num_rounds, use_custom_agents,
                       agent1_name, agent1_role, agent1_stance,
                       agent2_name, agent2_role, agent2_stance,
                       agent3_name, agent3_role, agent3_stance):
    """Enhanced debate with all features"""

    if not topic.strip():
        return "⚠️ Please enter a debate topic!", None, None

    # Create agents
    if use_custom_agents:
        agents = create_custom_agents(
            agent1_name, agent1_role, agent1_stance,
            agent2_name, agent2_role, agent2_stance,
            agent3_name, agent3_role, agent3_stance
        )
    else:
        agents = create_default_agents()

    debate_output = f"""# 🎭 MULTI-AGENT DEBATE SYSTEM

## 📋 Topic: {topic}

### 👥 Debate Participants:
- **{agents[0].name}** - {agents[0].role}
  - Stance: {agents[0].stance}
- **{agents[1].name}** - {agents[1].role}
  - Stance: {agents[1].stance}
- **{agents[2].name}** - {agents[2].role}
  - Stance: {agents[2].stance}

---

"""

    conversation_history = ""
    agent_scores = {agent.name: 0 for agent in agents}
    full_debate_data = {
        "topic": topic,
        "date": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "agents": [{"name": a.name, "role": a.role, "stance": a.stance} for a in agents],
        "rounds": []
    }

    for round_num in range(1, int(num_rounds) + 1):
        debate_output += f"\n## 🔄 Round {round_num}\n\n"

        round_arguments = []
        round_data = {"round_number": round_num, "arguments": []}

        for i, agent in enumerate(agents):
            previous_arg = round_arguments[-1] if round_arguments else ""

            debate_output += f"### 💬 {agent.name}\n"
            debate_output += f"*{agent.role}*\n\n"

            argument = agent.generate_argument(
                topic=topic,
                conversation_history=conversation_history[:300],
                opponent_argument=previous_arg
            )

            debate_output += f"{argument}\n\n"

            # Scoring
            score = len(argument.split())
            quality_keywords = ['evidence', 'research', 'data', 'study', 'however',
                              'therefore', 'because', 'consider', 'analysis', 'impact']
            score += sum(2 for word in quality_keywords if word in argument.lower())
            agent_scores[agent.name] += score

            round_arguments.append(argument)
            conversation_history += f"{agent.name}: {argument}\n"

            round_data["arguments"].append({
                "agent": agent.name,
                "argument": argument,
                "score": score
            })

            time.sleep(1)  # Rate limiting

        full_debate_data["rounds"].append(round_data)
        debate_output += f"\n---\n"

    # Final Analysis
    debate_output += f"\n## 🎯 Debate Analysis\n\n"

    ranked_agents = sorted(agent_scores.items(), key=lambda x: x[1], reverse=True)

    debate_output += "### 📊 Argument Strength Scores:\n\n"
    medals = ["🥇", "🥈", "🥉"]
    for idx, (agent_name, score) in enumerate(ranked_agents):
        medal = medals[idx] if idx < 3 else "🏅"
        debate_output += f"{medal} **{agent_name}**: {score} points\n"

    full_debate_data["scores"] = dict(ranked_agents)

    debate_output += f"\n### 💡 Key Takeaways:\n\n"
    debate_output += f"- **{agents[0].name}**: {agents[0].stance}\n"
    debate_output += f"- **{agents[1].name}**: {agents[1].stance}\n"
    debate_output += f"- **{agents[2].name}**: {agents[2].stance}\n\n"

    debate_output += f"### ✅ Conclusion:\n\n"
    debate_output += f"This multi-agent debate demonstrated diverse viewpoints on **{topic}**. "
    debate_output += f"Each agent contributed unique insights based on their expertise, "
    debate_output += f"showcasing how AI systems can simulate expert panel discussions.\n"

    # Save to history
    save_debate_to_history(full_debate_data)

    # Generate PDF
    pdf_filename = f"debate_{datetime.now().strftime('%Y%m%d_%H%M%S')}.pdf"
    pdf_path = export_debate_to_pdf(full_debate_data, pdf_filename)

    return debate_output, pdf_path, "✅ Debate saved to history!"

print("✅ Main debate function ready!")
# Out:
# ✅ Main debate function ready!

# %%
# Create the complete Gradio interface
with gr.Blocks(theme=gr.themes.Soft(), title="Multi-Agent AI Debate System") as demo:

    gr.Markdown("""
    # 🤖 Multi-Agent AI Debate System
    ### *Simulating Expert Panel Discussions with AI*

    **Features:** Custom Agents | Debate History | PDF Export | Argument Scoring

    This system uses multiple AI agents with different expertise and perspectives
    to engage in structured debates on complex topics.
    """)

    with gr.Tabs():
        # TAB 1: Main Debate
        with gr.Tab("🎬 Start Debate"):
            with gr.Row():
                with gr.Column(scale=1):
                    gr.Markdown("### ⚙️ Debate Configuration")

                    topic_input = gr.Textbox(
                        label="🎯 Debate Topic",
                        placeholder="Enter any topic for AI agents to debate...",
                        lines=3,
                        value="Should AI development be regulated by governments?"
                    )

                    rounds_input = gr.Slider(
                        minimum=1,
                        maximum=4,
                        value=2,
                        step=1,
                        label="🔄 Number of Rounds"
                    )

                    use_custom = gr.Checkbox(
                        label="Use Custom Agents",
                        value=False,
                        info="Enable to customize agent personalities"
                    )

                    debate_btn = gr.Button("🎬 Start Debate", variant="primary", size="lg")

                    gr.Markdown("### 🔥 Example Topics:")
                    gr.Examples(
                        examples=[
                            ["Should AI development be regulated by governments?"],
                            ["Is remote work better than office work?"],
                            ["Should social media be regulated?"],
                            ["Will AI create or destroy more jobs?"],
                        ],
                        inputs=[topic_input]
                    )

                with gr.Column(scale=2):
                    output_box = gr.Markdown(value="*Debate output will appear here...*")

                    with gr.Row():
                        pdf_output = gr.File(label="📄 Download PDF Report")
                        status_output = gr.Textbox(label="Status", interactive=False)

        # TAB 2: Custom Agents
        with gr.Tab("👥 Custom Agents"):
            gr.Markdown("### Customize Agent Personalities")
            gr.Markdown("Leave fields empty to use default agents")

            with gr.Row():
                with gr.Column():
                    gr.Markdown("#### Agent 1")
                    agent1_name = gr.Textbox(label="Name", placeholder="Dr. Sarah Chen")
                    agent1_role = gr.Textbox(label="Role/Expertise", placeholder="AI Ethics Researcher")
                    agent1_stance = gr.Textbox(
                        label="Stance",
                        placeholder="Cautious - emphasizes safety",
                        lines=2
                    )

                with gr.Column():
                    gr.Markdown("#### Agent 2")
                    agent2_name = gr.Textbox(label="Name", placeholder="Marcus Rivera")
                    agent2_role = gr.Textbox(label="Role/Expertise", placeholder="Tech Entrepreneur")
                    agent2_stance = gr.Textbox(
                        label="Stance",
                        placeholder="Optimistic - promotes innovation",
                        lines=2
                    )

                with gr.Column():
                    gr.Markdown("#### Agent 3")
                    agent3_name = gr.Textbox(label="Name", placeholder="Prof. Anika Sharma")
                    agent3_role = gr.Textbox(label="Role/Expertise", placeholder="Policy Expert")
                    agent3_stance = gr.Textbox(
                        label="Stance",
                        placeholder="Balanced - seeks middle ground",
                        lines=2
                    )

        # TAB 3: History
        with gr.Tab("📚 Debate History"):
            with gr.Row():
                with gr.Column(scale=1):
                    refresh_btn = gr.Button("🔄 Refresh History", variant="secondary")

                    debate_num = gr.Number(
                        label="Load Specific Debate #",
                        value=1,
                        precision=0
                    )
                    load_btn = gr.Button("📖 Load Debate", variant="primary")

                with gr.Column(scale=3):
                    history_output = gr.Markdown(value=format_history_for_display())

        # TAB 4: About
        with gr.Tab("ℹ️ About"):
            gr.Markdown("""
            ## About This Project

            **Multi-Agent AI Debate System** is an innovative application that simulates expert
            panel discussions using multiple AI agents with distinct perspectives.

            ### Key Features:
            - 🎭 **Three AI Agents**: Each with unique expertise and viewpoints
            - 📊 **Intelligent Scoring**: Automated evaluation of argument quality
            - 🔄 **Multi-Round Debates**: Configurable 1-4 round discussions
            - 👥 **Custom Agents**: Create your own agent personalities
            - 📚 **Debate History**: Review past debates
            - 📄 **PDF Export**: Download professional debate reports

            ### Technology Stack:
            - **Python 3.x**
            - **Transformers (Hugging Face)** - NLP models
            - **Gradio** - Interactive web interface
            - **GPT-2** - Text generation
            - **ReportLab** - PDF generation

            ### Use Cases:
            - Educational: Teaching critical thinking
            - Business: Exploring different strategies
            - Research: Studying multi-agent systems
            - Decision Support: Analyzing multiple perspectives

            ---

            **Created for:** Wipro AI Track Training Assessment
            **Project Type:** GenAI & Agentic AI Application
            **Date:** February 2026
            """)

    # Event handlers
    debate_btn.click(
        fn=run_debate_enhanced,
        inputs=[
            topic_input, rounds_input, use_custom,
            agent1_name, agent1_role, agent1_stance,
            agent2_name, agent2_role, agent2_stance,
            agent3_name, agent3_role, agent3_stance
        ],
        outputs=[output_box, pdf_output, status_output]
    )

    refresh_btn.click(
        fn=format_history_for_display,
        inputs=[],
        outputs=[history_output]
    )

    load_btn.click(
        fn=load_specific_debate,
        inputs=[debate_num],
        outputs=[history_output]
    )

print("✅ Interface created!")
print("🚀 Launching application...")

# Launch with public sharing enabled
demo.launch(share=True, debug=True)
# Out:
# /tmp/ipython-input-1039/398741273.py:2: DeprecationWarning: The 'theme' parameter in the Blocks constructor will be removed in Gradio 6.0. You will need to pass 'theme' to Blocks.launch() instead.
#   with gr.Blocks(theme=gr.themes.Soft(), title="Multi-Agent AI Debate System") as demo:
# ✅ Interface created!
# 🚀 Launching application...
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://05f095f306f7843efe.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://05f095f306f7843efe.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ...

# %%
# Create deployment files
import os

# Create a directory for deployment files
os.makedirs('/content/deployment_files', exist_ok=True)

# 1. Create app.py (main application file)
app_code = '''import gradio as gr
import time
import json
import os
from datetime import datetime
from transformers import pipeline
from reportlab.lib.pagesizes import letter
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.units import inch
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.enums import TA_CENTER, TA_LEFT
from reportlab.lib.colors import HexColor

# Initialize model
print("Loading model...")
generator = pipeline('text-generation', model='gpt2', device=-1)
print("Model loaded!")

HISTORY_FILE = "debate_history.json"

class DebateAgent:
    def __init__(self, name, role, expertise, stance):
        self.name = name
        self.role = role
        self.expertise = expertise
        self.stance = stance

    def generate_argument(self, topic, conversation_history="", opponent_argument=""):
        prompt = f"{self.name} argues: {self.stance} regarding {topic}. "

        try:
            response = generator(
                prompt,
                max_length=100,
                num_return_sequences=1,
                temperature=0.8,
                do_sample=True,
                pad_token_id=50256
            )[0]['generated_text']

            argument = response[len(prompt):].strip()
            sentences = argument.split('.')
            argument = '. '.join(sentences[:3]) + '.'

            return argument if argument else f"I believe {self.stance.lower()} This perspective considers {self.expertise}."

        except Exception as e:
            fallback_args = {
                "Cautious": f"Regarding {topic}, we must proceed carefully. The risks of moving too quickly without proper safeguards could have serious consequences. My expertise in {self.expertise} shows that a measured approach is essential.",
                "Optimistic": f"I believe {topic} presents tremendous opportunities. Innovation thrives when we embrace change and allow progress to move forward. Based on my experience in {self.expertise}, rapid advancement benefits everyone.",
                "Balanced": f"Considering {topic}, we need to weigh both benefits and risks carefully. My work in {self.expertise} has shown that the best solutions come from thoughtful analysis of multiple perspectives."
            }

            for key in fallback_args:
                if key.lower() in self.stance.lower():
                    return fallback_args[key]

            return f"From my perspective as a {self.role}, {topic} requires careful consideration of multiple factors including {self.expertise}."

def create_custom_agents(agent1_name, agent1_role, agent1_stance,
                        agent2_name, agent2_role, agent2_stance,
                        agent3_name, agent3_role, agent3_stance):
    agent1 = DebateAgent(
        name=agent1_name if agent1_name.strip() else "Agent 1",
        role=agent1_role if agent1_role.strip() else "Debater",
        expertise=agent1_role if agent1_role.strip() else "general topics",
        stance=agent1_stance if agent1_stance.strip() else "Cautious approach"
    )

    agent2 = DebateAgent(
        name=agent2_name if agent2_name.strip() else "Agent 2",
        role=agent2_role if agent2_role.strip() else "Debater",
        expertise=agent2_role if agent2_role.strip() else "general topics",
        stance=agent2_stance if agent2_stance.strip() else "Optimistic approach"
    )

    agent3 = DebateAgent(
        name=agent3_name if agent3_name.strip() else "Agent 3",
        role=agent3_role if agent3_role.strip() else "Debater",
        expertise=agent3_role if agent3_role.strip() else "general topics",
        stance=agent3_stance if agent3_stance.strip() else "Balanced approach"
    )

    return [agent1, agent2, agent3]

def create_default_agents():
    agent1 = DebateAgent(
        name="Dr. Sarah Chen",
        role="AI Ethics Researcher",
        expertise="artificial intelligence safety and ethics",
        stance="Cautious - believes we need strong safeguards and careful consideration"
    )

    agent2 = DebateAgent(
        name="Marcus Rivera",
        role="Tech Entrepreneur",
        expertise="innovation and business growth",
        stance="Optimistic - believes in rapid innovation and market-driven solutions"
    )

    agent3 = DebateAgent(
        name="Prof. Anika Sharma",
        role="Policy Expert",
        expertise="balancing innovation with public interest",
        stance="Balanced - seeks evidence-based middle ground approaches"
    )

    return [agent1, agent2, agent3]

def save_debate_to_history(debate_data):
    try:
        if os.path.exists(HISTORY_FILE):
            with open(HISTORY_FILE, 'r') as f:
                history = json.load(f)
        else:
            history = []

        history.append(debate_data)

        if len(history) > 50:
            history = history[-50:]

        with open(HISTORY_FILE, 'w') as f:
            json.dump(history, f, indent=2)
    except Exception as e:
        print(f"Error saving history: {e}")

def load_debate_history():
    try:
        if os.path.exists(HISTORY_FILE):
            with open(HISTORY_FILE, 'r') as f:
                return json.load(f)
        return []
    except Exception as e:
        print(f"Error loading history: {e}")
        return []

def format_history_for_display():
    history = load_debate_history()

    if not history:
        return "📝 No debate history yet. Start your first debate!"

    output = "# 📚 Debate History\\n\\n"
    output += f"**Total Debates:** {len(history)}\\n\\n---\\n\\n"

    for idx, debate in enumerate(reversed(history[-10:])):
        output += f"## Debate #{len(history) - idx}\\n\\n"
        output += f"**Topic:** {debate['topic']}\\n\\n"
        output += f"**Date:** {debate['date']}\\n\\n"
        output += f"**Participants:** {', '.join([a['name'] for a in debate['agents']])}\\n\\n"
        output += f"**Winner:** {list(debate['scores'].keys())[0]} ({debate['scores'][list(debate['scores'].keys())[0]]} points)\\n\\n"
        output += "---\\n\\n"

    return output

def load_specific_debate(debate_number):
    history = load_debate_history()

    if not history or debate_number < 1 or debate_number > len(history):
        return "❌ Debate not found!"

    debate = history[int(debate_number) - 1]

    output = f"# 🎭 Debate #{int(debate_number)}\\n\\n"
    output += f"## 📋 Topic: {debate['topic']}\\n\\n"
    output += f"**Date:** {debate['date']}\\n\\n"

    output += "### 👥 Participants:\\n"
    for agent in debate['agents']:
        output += f"- **{agent['name']}** - {agent['role']}\\n"

    output += "\\n---\\n\\n"

    for round_data in debate['rounds']:
        output += f"## Round {round_data['round_number']}\\n\\n"
        for arg_data in round_data['arguments']:
            output += f"**{arg_data['agent']}:**\\n{arg_data['argument']}\\n\\n"
        output += "---\\n\\n"

    output += "## 📊 Final Scores:\\n\\n"
    medals = ["🥇", "🥈", "🥉"]
    for idx, (agent, score) in enumerate(debate['scores'].items()):
        medal = medals[idx] if idx < 3 else "🏅"
        output += f"{medal} **{agent}**: {score} points\\n"

    return output

def export_debate_to_pdf(debate_data, filename="debate_output.pdf"):
    try:
        doc = SimpleDocTemplate(filename, pagesize=letter)
        styles = getSampleStyleSheet()
        story = []

        title_style = ParagraphStyle(
            'CustomTitle',
            parent=styles['Heading1'],
            fontSize=24,
            textColor=HexColor('#2563eb'),
            spaceAfter=30,
            alignment=TA_CENTER
        )

        heading_style = ParagraphStyle(
            'CustomHeading',
            parent=styles['Heading2'],
            fontSize=14,
            textColor=HexColor('#1e40af'),
            spaceAfter=12,
            spaceBefore=12
        )

        story.append(Paragraph("🎭 Multi-Agent AI Debate System", title_style))
        story.append(Spacer(1, 0.2*inch))

        story.append(Paragraph(f"<b>Topic:</b> {debate_data['topic']}", styles['Normal']))
        story.append(Paragraph(f"<b>Date:</b> {debate_data['date']}", styles['Normal']))
        story.append(Spacer(1, 0.3*inch))

        story.append(Paragraph("Debate Participants", heading_style))
        for agent in debate_data['agents']:
            story.append(Paragraph(f"• <b>{agent['name']}</b> - {agent['role']}", styles['Normal']))
            story.append(Paragraph(f"  Stance: {agent['stance']}", styles['Normal']))
            story.append(Spacer(1, 0.1*inch))

        story.append(Spacer(1, 0.3*inch))

        for round_data in debate_data['rounds']:
            story.append(Paragraph(f"Round {round_data['round_number']}", heading_style))

            for arg_data in round_data['arguments']:
                story.append(Paragraph(f"<b>{arg_data['agent']}</b>", styles['Normal']))
                story.append(Paragraph(arg_data['argument'], styles['Normal']))
                story.append(Spacer(1, 0.15*inch))

            story.append(Spacer(1, 0.2*inch))

        story.append(Paragraph("Final Scores", heading_style))
        medals = ["🥇 ", "🥈 ", "🥉 "]
        for idx, (agent, score) in enumerate(debate_data['scores'].items()):
            medal = medals[idx] if idx < 3 else "🏅 "
            story.append(Paragraph(f"{medal}<b>{agent}</b>: {score} points", styles['Normal']))

        doc.build(story)

        return filename
    except Exception as e:
        print(f"Error creating PDF: {e}")
        return None

def run_debate_enhanced(topic, num_rounds, use_custom_agents,
                       agent1_name, agent1_role, agent1_stance,
                       agent2_name, agent2_role, agent2_stance,
                       agent3_name, agent3_role, agent3_stance):

    if not topic.strip():
        return "⚠️ Please enter a debate topic!", None, None

    if use_custom_agents:
        agents = create_custom_agents(
            agent1_name, agent1_role, agent1_stance,
            agent2_name, agent2_role, agent2_stance,
            agent3_name, agent3_role, agent3_stance
        )
    else:
        agents = create_default_agents()

    debate_output = f"""# 🎭 MULTI-AGENT DEBATE SYSTEM

## 📋 Topic: {topic}

### 👥 Debate Participants:
- **{agents[0].name}** - {agents[0].role}
  - Stance: {agents[0].stance}
- **{agents[1].name}** - {agents[1].role}
  - Stance: {agents[1].stance}
- **{agents[2].name}** - {agents[2].role}
  - Stance: {agents[2].stance}

---

"""

    conversation_history = ""
    agent_scores = {agent.name: 0 for agent in agents}
    full_debate_data = {
        "topic": topic,
        "date": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "agents": [{"name": a.name, "role": a.role, "stance": a.stance} for a in agents],
        "rounds": []
    }

    for round_num in range(1, int(num_rounds) + 1):
        debate_output += f"\\n## 🔄 Round {round_num}\\n\\n"

        round_arguments = []
        round_data = {"round_number": round_num, "arguments": []}

        for i, agent in enumerate(agents):
            previous_arg = round_arguments[-1] if round_arguments else ""

            debate_output += f"### 💬 {agent.name}\\n"
            debate_output += f"*{agent.role}*\\n\\n"

            argument = agent.generate_argument(
                topic=topic,
                conversation_history=conversation_history[:300],
                opponent_argument=previous_arg
            )

            debate_output += f"{argument}\\n\\n"

            score = len(argument.split())
            quality_keywords = ['evidence', 'research', 'data', 'study', 'however',
                              'therefore', 'because', 'consider', 'analysis', 'impact']
            score += sum(2 for word in quality_keywords if word in argument.lower())
            agent_scores[agent.name] += score

            round_arguments.append(argument)
            conversation_history += f"{agent.name}: {argument}\\n"

            round_data["arguments"].append({
                "agent": agent.name,
                "argument": argument,
                "score": score
            })

            time.sleep(1)

        full_debate_data["rounds"].append(round_data)
        debate_output += f"\\n---\\n"

    debate_output += f"\\n## 🎯 Debate Analysis\\n\\n"

    ranked_agents = sorted(agent_scores.items(), key=lambda x: x[1], reverse=True)

    debate_output += "### 📊 Argument Strength Scores:\\n\\n"
    medals = ["🥇", "🥈", "🥉"]
    for idx, (agent_name, score) in enumerate(ranked_agents):
        medal = medals[idx] if idx < 3 else "🏅"
        debate_output += f"{medal} **{agent_name}**: {score} points\\n"

    full_debate_data["scores"] = dict(ranked_agents)

    debate_output += f"\\n### 💡 Key Takeaways:\\n\\n"
    debate_output += f"- **{agents[0].name}**: {agents[0].stance}\\n"
    debate_output += f"- **{agents[1].name}**: {agents[1].stance}\\n"
    debate_output += f"- **{agents[2].name}**: {agents[2].stance}\\n\\n"

    debate_output += f"### ✅ Conclusion:\\n\\n"
    debate_output += f"This multi-agent debate demonstrated diverse viewpoints on **{topic}**. "
    debate_output += f"Each agent contributed unique insights based on their expertise.\\n"

    save_debate_to_history(full_debate_data)

    pdf_filename = f"debate_{datetime.now().strftime('%Y%m%d_%H%M%S')}.pdf"
    pdf_path = export_debate_to_pdf(full_debate_data, pdf_filename)

    return debate_output, pdf_path, "✅ Debate saved to history!"

# Create Gradio interface
with gr.Blocks(theme=gr.themes.Soft(), title="Multi-Agent AI Debate System") as demo:

    gr.Markdown("""
    # 🤖 Multi-Agent AI Debate System
    ### *Simulating Expert Panel Discussions with AI*

    **Features:** Custom Agents | Debate History | PDF Export | Argument Scoring
    """)

    with gr.Tabs():
        with gr.Tab("🎬 Start Debate"):
            with gr.Row():
                with gr.Column(scale=1):
                    gr.Markdown("### ⚙️ Debate Configuration")

                    topic_input = gr.Textbox(
                        label="🎯 Debate Topic",
                        placeholder="Enter any topic...",
                        lines=3,
                        value="Should AI development be regulated by governments?"
                    )

                    rounds_input = gr.Slider(
                        minimum=1,
                        maximum=4,
                        value=2,
                        step=1,
                        label="🔄 Number of Rounds"
                    )

                    use_custom = gr.Checkbox(
                        label="Use Custom Agents",
                        value=False
                    )

                    debate_btn = gr.Button("🎬 Start Debate", variant="primary", size="lg")

                    gr.Examples(
                        examples=[
                            ["Should AI development be regulated by governments?"],
                            ["Is remote work better than office work?"],
                            ["Should social media be regulated?"],
                        ],
                        inputs=[topic_input]
                    )

                with gr.Column(scale=2):
                    output_box = gr.Markdown(value="*Debate output will appear here...*")

                    with gr.Row():
                        pdf_output = gr.File(label="📄 Download PDF")
                        status_output = gr.Textbox(label="Status", interactive=False)

        with gr.Tab("👥 Custom Agents"):
            gr.Markdown("### Customize Agent Personalities")

            with gr.Row():
                with gr.Column():
                    gr.Markdown("#### Agent 1")
                    agent1_name = gr.Textbox(label="Name", placeholder="Dr. Sarah Chen")
                    agent1_role = gr.Textbox(label="Role", placeholder="AI Ethics Researcher")
                    agent1_stance = gr.Textbox(label="Stance", placeholder="Cautious", lines=2)

                with gr.Column():
                    gr.Markdown("#### Agent 2")
                    agent2_name = gr.Textbox(label="Name", placeholder="Marcus Rivera")
                    agent2_role = gr.Textbox(label="Role", placeholder="Tech Entrepreneur")
                    agent2_stance = gr.Textbox(label="Stance", placeholder="Optimistic", lines=2)

                with gr.Column():
                    gr.Markdown("#### Agent 3")
                    agent3_name = gr.Textbox(label="Name", placeholder="Prof. Anika Sharma")
                    agent3_role = gr.Textbox(label="Role", placeholder="Policy Expert")
                    agent3_stance = gr.Textbox(label="Stance", placeholder="Balanced", lines=2)

        with gr.Tab("📚 History"):
            with gr.Row():
                with gr.Column(scale=1):
                    refresh_btn = gr.Button("🔄 Refresh", variant="secondary")
                    debate_num = gr.Number(label="Load Debate #", value=1, precision=0)
                    load_btn = gr.Button("📖 Load", variant="primary")

                with gr.Column(scale=3):
                    history_output = gr.Markdown(value=format_history_for_display())

        with gr.Tab("ℹ️ About"):
            gr.Markdown("""
            ## Multi-Agent AI Debate System

            Created for Wipro AI Track Training Assessment

            ### Features:
            - 🎭 Three AI agents with unique perspectives
            - 📊 Automated argument scoring
            - 📄 PDF export functionality
            - 📚 Debate history tracking
            - 👥 Customizable agent personalities

            ### Tech Stack:
            - Python, Transformers, Gradio, GPT-2, ReportLab
            """)

    debate_btn.click(
        fn=run_debate_enhanced,
        inputs=[
            topic_input, rounds_input, use_custom,
            agent1_name, agent1_role, agent1_stance,
            agent2_name, agent2_role, agent2_stance,
            agent3_name, agent3_role, agent3_stance
        ],
        outputs=[output_box, pdf_output, status_output]
    )

    refresh_btn.click(
        fn=format_history_for_display,
        outputs=[history_output]
    )

    load_btn.click(
        fn=load_specific_debate,
        inputs=[debate_num],
        outputs=[history_output]
    )

if __name__ == "__main__":
    demo.launch()
'''

with open('/content/deployment_files/app.py', 'w') as f:
    f.write(app_code)

# 2. Create requirements.txt
requirements = '''transformers
torch
gradio
reportlab
accelerate
'''

with open('/content/deployment_files/requirements.txt', 'w') as f:
    f.write(requirements)

# 3. Create README.md
readme = '''---
title: Multi-Agent AI Debate System
emoji: 🤖
colorFrom: blue
colorTo: purple
sdk: gradio
sdk_version: 4.0.0
app_file: app.py
pinned: false
---

# Multi-Agent AI Debate System

Simulating expert panel discussions using AI agents with different perspectives.

## Features
- 🎭 Three AI agents with unique viewpoints
- 📊 Automated argument scoring
- 📄 PDF export
- 📚 Debate history
- 👥 Custom agent personalities
'''

with open('/content/deployment_files/README.md', 'w') as f:
    f.write(readme)

print("✅ All deployment files created!")
print("\nFiles created in /content/deployment_files/:")
print("  - app.py")
print("  - requirements.txt")
print("  - README.md")
# Out:
# ✅ All deployment files created!
#
# Files created in /content/deployment_files/:
#   - app.py
#   - requirements.txt
#   - README.md

# %%
# Zip all files for easy download
# !cd /content/deployment_files && zip -r deployment_files.zip .
print("✅ Files zipped!")
print("\nNow download the zip file:")

from google.colab import files
files.download('/content/deployment_files/deployment_files.zip')
# Out:
#   adding: app.py (deflated 73%)
#   adding: requirements.txt (deflated 4%)
#   adding: README.md (deflated 34%)
# ✅ Files zipped!
#
# Now download the zip file:
